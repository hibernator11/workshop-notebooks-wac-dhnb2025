# %% [markdown]
# # Harvesting collections of text from archived web pages

# %% [markdown]
# This notebook helps you assemble datasets of text extracted from all available captures of archived web pages. You can then feed these datasets to the text analysis tool of your choice to analyse changes over time.
#
# ### Harvest sources
#
# * Timemaps – harvest text from a single url, or list of urls, using the repository of your choice
# * CDX API – harvest text from the results of a query to the Internet Archive's CDX API
#
# ### Options
#
# * `filter_text=False` (default) – save all of the human visible text on the page, this includes boilerplate, footers, and navigation text.
# * `filter_text=True` – save only the significant text on the page, excluding recurring items like boilerplate and navigation. This is done by [Trafilatura](https://trafilatura.readthedocs.io/en/latest/index.html).
#
# ### Usage
#
# #### Using Timemaps
#
# ``` python
# get_texts_for_url([timegate], [url], filter_text=[True or False])
#
# ```
#
# The `timegate` value should be one of:
#
# * `nla` – National Library of Australia
# * `nlnz` – National Library of New Zealand
# * `bl` – UK Web Archive
# * `ia` – Internet Archive
# * `ukgwa` – UK Government Web Archive
#
# #### Using the Internet Archive's CDX API
#
# Use a CDX query to find all urls that include the specified keyword in their url.
#
# ``` python
# get_texts_for_cdx_query([url], filter_text=[True or False], filter=['original:.*[keyword].*', 'statuscode:200', 'mimetype:text/html'])
# ```
#
# The `url` value can use wildcards to indicate whether it is a domain or prefix query, for example:
#
# * `nla.gov.au/*` – prefix query, search all files under `nla.gov.au`
# * `*.nla.gov.au` – domain query, search all files under `nla.gov.au` and any of its subdomains
#
# You can use any of the keyword parameters that the CDX API recognises, but you probably want to filter for `statuscode` and `mimetype` and apply some sort of regular expression to `original`.
#
# ### Output
#
# A directory will be created for each url processed. The name of the directory will be a slugified version of the url in SURT (Sort-friendly URI Reordering Transform) format.
#
# Each text file will be saved separately within the directory. Filenames follow the pattern:
#
# ```
# [SURT formatted url]-[capture timestamp].txt
# ```
#
# There's also a `metadata.json` file that includes basic details of the harvest:
#
# * `timegate` - the repository used
# * `url` – the url harvested
# * `filter_text` – text filtering option used
# * `date` – date and time the harvest was started
# * `mementos` – details of each capture, including:
#     * `url` – link to capture in web archive
#     * `file_path` – path to harvested text file

# %% [markdown]
# ## Import what we need

# %%
import json
import re
import time
from pathlib import Path

import arrow
import pandas as pd
import requests
import trafilatura
from bs4 import BeautifulSoup
from IPython.display import FileLink, FileLinks, display
from lxml.etree import ParserError
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from slugify import slugify
from surt import surt
from tqdm.auto import tqdm

s = requests.Session()
retries = Retry(total=10, backoff_factor=1, status_forcelist=[502, 503, 504])
s.mount("https://", HTTPAdapter(max_retries=retries))
s.mount("http://", HTTPAdapter(max_retries=retries))

# %%
# Default list of repositories -- you could add to this
TIMEGATES = {
    "nla": "https://web.archive.org.au/awa/",
    "nlnz": "https://ndhadeliver.natlib.govt.nz/webarchive/",
    "bl": "https://www.webarchive.org.uk/wayback/archive/",
    "ia": "https://web.archive.org/web/",
    "ukgwa": "https://webarchive.nationalarchives.gov.uk/ukgwa/",
}

# %% [markdown]
# ## Define some functions

# %%
def is_memento(url):
    """
    Is this url a Memento? Checks for the presence of a timestamp.
    """
    return bool(re.search(r"/(\d{12}|\d{14})(?:id_|mp_|if_)*/http", url))


def get_html(url):
    """
    Retrieve the original HTML content of an archived page.
    Follow redirects if they go to another archived page.
    Return the (possibly redirected) url from the response and the HTML content.
    """
    # Adding the id_ hint tells the archive to give us the original harvested version, without any rewriting.
    url = re.sub(r"/(\d{12}|\d{14})(?:mp_)*/http", r"/\1id_/http", url)
    response = ""
    try:
        response = requests.get(url, allow_redirects=True)
    except:
        print("get_html error url connection:" + url)
    # Some captures might redirect themselves to live versions
    # If the redirected url doesn't look like a Memento rerun this without redirection
    if response != "" and not is_memento(response.url):
        response = requests.get(url, allow_redirects=False)
    if response == "":
        return {"url": "error_connection", "html": "error_connection"}    
    else:
        return {"url": response.url, "html": response.content}


def convert_lists_to_dicts(results):
    """
    Converts IA style timemap (a JSON array of arrays) to a list of dictionaries.
    Renames keys to standardise IA with other Timemaps.
    """
    if results:
        keys = results[0]
        results_as_dicts = [dict(zip(keys, v)) for v in results[1:]]
    else:
        results_as_dicts = results
    # Rename keys
    for d in results_as_dicts:
        d["status"] = d.pop("statuscode")
        d["mime"] = d.pop("mimetype")
        d["url"] = d.pop("original")
    return results_as_dicts


def get_capture_data_from_memento(url, request_type="head"):
    """
    For OpenWayback systems this can get some extra cpature info to insert in Timemaps.
    """
    if request_type == "head":
        response = requests.head(url)
    else:
        response = requests.get(url)
    headers = response.headers
    length = headers.get("x-archive-orig-content-length")
    status = headers.get("x-archive-orig-status")
    status = status.split(" ")[0] if status else None
    mime = headers.get("x-archive-orig-content-type")
    mime = mime.split(";")[0] if mime else None
    return {"length": length, "status": status, "mime": mime}


def convert_link_to_json(results, enrich_data=False):
    """
    Converts link formatted Timemap to JSON.
    """
    data = []
    for line in results.splitlines():
        parts = line.split("; ")
        if len(parts) > 1:
            link_type = re.search(
                r'rel="(original|self|timegate|first memento|last memento|memento)"',
                parts[1],
            ).group(1)
            if link_type == "memento":
                link = parts[0].strip("<>")
                timestamp, original = re.search(r"/(\d{12}|\d{14})/(.*)$", link).groups()
                capture = {"timestamp": timestamp, "url": original}
                if enrich_data:
                    capture.update(get_capture_data_from_memento(link))
                data.append(capture)
    return data


def get_timemap_as_json(timegate, url):
    """
    Get a Timemap then normalise results (if necessary) to return a list of dicts.
    """
    tg_url = f"{TIMEGATES[timegate]}timemap/json/{url}/"
    print(tg_url)
    response = requests.get(tg_url)
    response_type = response.headers["content-type"]
    # pywb style Timemap
    if response_type == "text/x-ndjson":
        data = [json.loads(line) for line in response.text.splitlines()]
    # IA Wayback stype Timemap
    elif response_type == "application/json":
        data = convert_lists_to_dicts(response.json())
    # Link style Timemap (OpenWayback)
    elif response_type in ["application/link-format", "text/html;charset=utf-8"]:
        data = convert_link_to_json(response.text)
    return data


def get_all_text(capture_data):
    """
    Get all the human visible text from a web page, including headers, footers, and navigation.
    Does some cleaning up to remove multiple spaces, tabs, and newlines.
    """
    try:
        text = BeautifulSoup(capture_data["html"]).get_text()
    except TypeError:
        return None
    else:
        # Remove multiple newlines
        text = re.sub(r"\n\s*\n", "\n\n", text)
        # Remove multiple spaces or tabs with a single space
        text = re.sub(r"( |\t){2,}", " ", text)
        # Remove leading spaces
        text = re.sub(r"\n ", "\n", text)
        # Remove leading newlines
        text = re.sub(r"^\n*", "", text)
        return text


def get_main_text(capture_data):
    """
    Get only the main text from a page, excluding boilerplate and navigation.
    """
    try:
        text = trafilatura.extract(capture_data["html"])
    except ParserError:
        text = ""
    return text


def get_text_from_capture(capture_url, filter_text=False):
    """
    Get text from the given memento.
    If filter_text is True, only return the significant text (excluding things like navigation).
    """
    capture_data = get_html(capture_url)
    if filter_text:
        text = get_main_text(capture_data)
    else:
        text = get_all_text(capture_data)
    return text


def process_capture_list(timegate, captures, filter_text=False, url=None):
    if not url:
        url = captures[0]["url"]
    metadata = {
        "timegate": TIMEGATES[timegate],
        "url": url,
        "filter_text": filter_text,
        "date": arrow.now().format("YYYY-MM-DD HH:mm:ss"),
        "mementos": [],
    }
    try:
        urlkey = captures[0]["urlkey"]
    except KeyError:
        urlkey = surt(url)
    # Truncate urls longer than 50 chars so that filenames are not too long
    output_dir = Path("text-" + timegate, slugify(urlkey)[:50])
    output_dir.mkdir(parents=True, exist_ok=True)
    
    for capture in tqdm(captures, desc="Captures"):
        file_path = Path(
            output_dir, f'{slugify(urlkey)[:50]}-{capture["timestamp"]}.txt'
        )
        # Don't reharvest if file already exists
        if not file_path.exists():
            # Only process successful captures
            if capture["status"] == "200":
                capture_url = (
                    f'{TIMEGATES[timegate]}{capture["timestamp"]}id_/{capture["url"]}'
                )
                capture_text = get_text_from_capture(capture_url, filter_text)
                if capture_text:
                    # Truncate urls longer than 50 chars so that filenames are not too long
                    file_path = Path(
                        output_dir, f'{slugify(urlkey)[:50]}-{capture["timestamp"]}.txt'
                    )
                    file_path.write_text(capture_text)
                    metadata["mementos"].append(
                        {"url": capture_url, "text_file": str(file_path)}
                    )
                time.sleep(0.2)
    metadata_file = Path(output_dir, "metadata.json")
    with metadata_file.open("wt") as md_json:
        json.dump(metadata, md_json)


def save_texts_from_url(timegate, url, filter_text=False):
    """
    Save the text contents of all available captures for a given url from the specified repository.
    Saves both the harvested text files and a json file with the harvest metadata.
    """
    timemap = get_timemap_as_json(timegate, url)
    if timemap:
        process_capture_list(timegate, timemap, url=url, filter_text=filter_text)


def prepare_params(url, **kwargs):
    """
    Prepare the parameters for a CDX API requests.
    Adds all supplied keyword arguments as parameters (changing from_ to from).
    Adds in a few necessary parameters.
    """
    params = kwargs
    params["url"] = url
    params["output"] = "json"
    params["pageSize"] = 5
    # CDX accepts a 'from' parameter, but this is a reserved word in Python
    # Use 'from_' to pass the value to the function & here we'll change it back to 'from'.
    if "from_" in params:
        params["from"] = params["from_"]
        del params["from_"]
    return params


def get_total_pages(params):
    """
    Get number of pages in a query.
    Note that the number of pages doesn't tell you much about the number of results, as the numbers per page vary.
    """
    these_params = params.copy()
    these_params["showNumPages"] = "true"
    print(these_params)
    response = s.get(
        "http://web.archive.org/cdx/search/cdx",
        params=these_params,
        headers={"User-Agent": ""},
    ) 
    data = json.loads(response.text)
    
    return int(data[1][0])


def get_cdx_data(params):
    """
    Make a request to the CDX API using the supplied parameters.
    Return results converted to a list of dicts.
    """
    response = s.get("http://web.archive.org/cdx/search/cdx", params=params)
    response.raise_for_status()
    results = response.json()
    try:
        if not response.from_cache:
            time.sleep(0.2)
    except AttributeError:
        # Not using cache
        time.sleep(0.2)
    return convert_lists_to_dicts(results)


def harvest_cdx_query(url, **kwargs):
    """
    Harvest results of query from the IA CDX API using pagination.
    Returns captures as a list of dicts.
    """
    results = []
    page = 0
    params = prepare_params(url, **kwargs)
    total_pages = get_total_pages(params)
    with tqdm(total=total_pages - page, desc="CDX") as pbar:
        while page < total_pages:
            params["page"] = page
            results += get_cdx_data(params)
            page += 1
            pbar.update(1)
    return results


def save_texts_from_cdx_query(url, filter_text=False, **kwargs):
    captures = harvest_cdx_query(url, **kwargs)
    if captures:
        df = pd.DataFrame(captures)
        groups = df.groupby(by="urlkey")
        print(f"{len(groups)} matching urls")
        for name, group in groups:
            process_capture_list(
                "ia", group.to_dict("records"), filter_text=filter_text
            )

# %% [markdown]
# ## Harvesting a single url or list of urls
#
# Get all human-visible text from all captures of a single url in the UK Government Web Archive.

# %%
save_texts_from_url("ukgwa", "http://www.britishcouncil.org", filter_text=False)
# Out:
# https://webarchive.nationalarchives.gov.uk/ukgwa/timemap/json/http://www.britishcouncil.org/
# Captures:   0%|          | 0/1183 [00:00<?, ?it/s]

# %% [markdown]
# ## Viewing and downloading the results
#
# If you're using Jupyter Lab, you can browse the results of this notebook by just looking inside the `text` folder. I've also enabled the `jupyter-archive` extension which adds a download option to the right-click menu. Just right click on a folder and you'll see an option to 'Download as an Archive'. This will zip up and download the folder.
#
# The cells below provide a couple of alternative ways of viewing and downloading the results.

# %%
# Display all the files under the current text folder (this could be a long list)
display(FileLinks("text-ukgwa"))
# Out:
# text-ukgwa/org-britishcouncil/
#   org-britishcouncil-20211029152650.txt
#   org-britishcouncil-20120803134532.txt
#   org-britishcouncil-20201001015153.txt
#   org-britishcouncil-20220702185626.txt
#   org-britishcouncil-20121016151724.txt
#   org-britishcouncil-20180328090718.txt
#   org-britishcouncil-20220503190857.txt
#   org-britishcouncil-20221223140215.txt
#   org-britishcouncil-20120801134109.txt
#   org-britishcouncil-20150418072147.txt
#   org-britishcouncil-20220207172355.txt
#   org-britishcouncil-20150522162127.txt
#   org-britishcouncil-20141216172411.txt
#   org-britishcouncil-20220424201511.txt
#   org-britishcouncil-20220610201941.txt
#   org-britishcouncil-20140624170436.txt
#   org-britishcouncil-20220916200846.txt
#   org-britishcouncil-20230411211441.txt
#   org-britishcouncil-20220212110532.txt
#   org-britishcouncil-20170717155714.txt
#   org-britishcouncil-20120912164205.txt
#   org-britishcouncil-20160704112554.txt
#   org-britishcouncil-20180311165000.txt
#   org-britishcouncil-20241010093731.txt
#   org-britishcouncil-20140404122542.txt
#   org-britishcouncil-20241010093845.txt
#   org-britishcouncil-20220625194059.txt
#   org-britishcouncil-20200318162517.txt
#   org-britishcouncil-20180206215511.txt
#   org-britishcouncil-20061016224156.txt
#   org-britishcouncil-20210301083848.txt
#   org-britishcouncil-20201023102911.txt
#   org-britishcouncil-20121003233714.txt
#   org-britishcouncil-20220202011029.txt
#   org-britishcouncil-20170426132430.txt
#   org-britishcouncil-20220528013503.txt
#   org-britishcouncil-20170803115705.txt
#   org-britishcouncil-20120802111712.txt
#   org-britishcouncil-20130803000941.txt
#   org-britishcouncil-20220210170957.txt
#   org-britishcouncil-20221014151339.txt
#   org-britishcouncil-20121205162453.txt
#   org-britishcouncil-20130104125829.txt
#   org-britishcouncil-20221118230337.txt
#   org-britishcouncil-20230310203915.txt
#   org-britishcouncil-20131210185900.txt
#   org-britishcouncil-20230505205528.txt
#   org-britishcouncil-20130123185521.txt
#   org-britishcouncil-20121017163354.txt
#   org-britishcouncil-20220805202719.txt
#   org-britishcouncil-20140504145212.txt
#   org-britishcouncil-20040131040242.txt
#   org-britishcouncil-20210605002128.txt
#   org-britishcouncil-20191122142653.txt
#   org-britishcouncil-20231006142506.txt
#   org-britishcouncil-20120708133430.txt
#   org-britishcouncil-20120712120249.txt
#   org-britishcouncil-20230622125619.txt
#   org-britishcouncil-20190613115854.txt
#   org-britishcouncil-20230325085352.txt
#   org-britishcouncil-20120804022053.txt
#   org-britishcouncil-20200630192607.txt
#   org-britishcouncil-20190510201720.txt
#   org-britishcouncil-20190103005101.txt
#   org-britishcouncil-20190613151227.txt
#   org-britishcouncil-20210104150714.txt
#   org-britishcouncil-20220930191115.txt
#   org-britishcouncil-20140618011811.txt
#   org-britishcouncil-20201130190807.txt
#   org-britishcouncil-20210709023712.txt
#   org-britishcouncil-20190701161213.txt
#   org-britishcouncil-20220323181354.txt
#   org-britishcouncil-20230310131103.txt
#   org-britishcouncil-20200409104601.txt
#   org-britishcouncil-20200626115011.txt
#   org-britishcouncil-20240906045145.txt
#   org-britishcouncil-20200914125140.txt
#   org-britishcouncil-20140615223557.txt
#   org-britishcouncil-20200420212717.txt
#   org-britishcouncil-20230616144728.txt
#   org-britishcouncil-20190613172444.txt
#   org-britishcouncil-20210916192353.txt
#   org-britishcouncil-20220812235111.txt
#   org-britishcouncil-20220429151216.txt
#   org-britishcouncil-20130614173015.txt
#   org-britishcouncil-20220610160053.txt
#   org-britishcouncil-20221217043201.txt
#   org-britishcouncil-20221118165338.txt
#   org-britishcouncil-20120627152524.txt
#   org-britishcouncil-20210319115958.txt
#   org-britishcouncil-20210112203446.txt
#   org-britishcouncil-20210619011154.txt
#   org-britishcouncil-20140909123503.txt
#   org-britishcouncil-20210709185522.txt
#   org-britishcouncil-20231201141120.txt
#   org-britishcouncil-20181204172046.txt
#   org-britishcouncil-20120831010848.txt
#   org-britishcouncil-20240104153534.txt
#   org-britishcouncil-20230513023122.txt
#   org-britishcouncil-20120704142703.txt
#   org-britishcouncil-20170302143305.txt
#   org-britishcouncil-20160902134715.txt
#   org-britishcouncil-20210108162658.txt
#   org-britishcouncil-20220215181729.txt
#   org-britishcouncil-20190902114931.txt
#   org-britishcouncil-20120619074341.txt
#   org-britishcouncil-20190902211849.txt
#   org-britishcouncil-20210407131509.txt
#   org-britishcouncil-20230707200705.txt
#   org-britishcouncil-20230411150706.txt
#   org-britishcouncil-20210602153917.txt
#   org-britishcouncil-20200403104424.txt
#   org-britishcouncil-20121014105640.txt
#   org-britishcouncil-20121015113509.txt
#   org-britishcouncil-20220930151941.txt
#   org-britishcouncil-20190111165431.txt
#   org-britishcouncil-20230426002553.txt
#   org-britishcouncil-20211120010908.txt
#   org-britishcouncil-20181221131238.txt
#   org-britishcouncil-20220722212310.txt
#   org-britishcouncil-20120719162251.txt
#   org-britishcouncil-20041109000712.txt
#   org-britishcouncil-20210811234650.txt
#   org-britishcouncil-20220108024441.txt
#   org-britishcouncil-20120704151705.txt
#   org-britishcouncil-20220910023654.txt
#   org-britishcouncil-20220204165308.txt
#   org-britishcouncil-20120809151836.txt
#   org-britishcouncil-20200814120850.txt
#   org-britishcouncil-20200507151800.txt
#   org-britishcouncil-20211224223555.txt
#   org-britishcouncil-20130201195326.txt
#   org-britishcouncil-20230428210236.txt
#   org-britishcouncil-20230203193938.txt
#   org-britishcouncil-20130704100115.txt
#   org-britishcouncil-20080709094600.txt
#   org-britishcouncil-20230401031343.txt
#   org-britishcouncil-20210205162450.txt
#   org-britishcouncil-20150331171441.txt
#   org-britishcouncil-20180209054938.txt
#   org-britishcouncil-20120619022720.txt
#   org-britishcouncil-20220407161308.txt
#   org-britishcouncil-20220206080803.txt
#   org-britishcouncil-20221104163514.txt
#   org-britishcouncil-20220218112051.txt
#   org-britishcouncil-20061031212445.txt
#   org-britishcouncil-20130307180750.txt
#   org-britishcouncil-20220401153603.txt
#   org-britishcouncil-20221230184559.txt
#   org-britishcouncil-20211210162712.txt
#   org-britishcouncil-20130730093929.txt
#   org-britishcouncil-20121021135730.txt
#   org-britishcouncil-20210724043155.txt
#   org-britishcouncil-20120803160124.txt
#   org-britishcouncil-20121204113407.txt
#   org-britishcouncil-20170804142550.txt
#   org-britishcouncil-20080722121936.txt
#   org-britishcouncil-20200207071136.txt
#   org-britishcouncil-20221125210338.txt
#   org-britishcouncil-20220722123013.txt
#   org-britishcouncil-20211007034337.txt
#   org-britishcouncil-20230224232907.txt
#   org-britishcouncil-20200612145218.txt
#   org-britishcouncil-20120804071456.txt
#   org-britishcouncil-20230210203515.txt
#   org-britishcouncil-20041109032654.txt
#   org-britishcouncil-20150423102947.txt
#   org-britishcouncil-20070506130531.txt
#   org-britishcouncil-20201113134732.txt
#   org-britishcouncil-20120808133448.txt
#   org-britishcouncil-20220513183527.txt
#   org-britishcouncil-20210514102845.txt
#   org-britishcouncil-20201104140701.txt
#   org-britishcouncil-20120913101517.txt
#   org-britishcouncil-20160921102502.txt
#   org-britishcouncil-20120904102835.txt
#   org-britishcouncil-20230318070411.txt
#   org-britishcouncil-20221007234120.txt
#   org-britishcouncil-20210430153039.txt
#   org-britishcouncil-20200505092030.txt
#   org-britishcouncil-20120815130145.txt
#   org-britishcouncil-20230908131453.txt
#   org-britishcouncil-20120829114102.txt
#   org-britishcouncil-20201230163544.txt
#   org-britishcouncil-20120614164946.txt
#   org-britishcouncil-20130923112102.txt
#   org-britishcouncil-20200102160242.txt
#   org-britishcouncil-20200302102937.txt
#   org-britishcouncil-20180328090417.txt
#   org-britishcouncil-20220606101037.txt
#   org-britishcouncil-20120904114353.txt
#   org-britishcouncil-20220402141702.txt
#   org-britishcouncil-20220214190730.txt
#   org-britishcouncil-20200625122527.txt
#   org-britishcouncil-20190613140828.txt
#   org-britishcouncil-20201209150332.txt
#   org-britishcouncil-20120719031415.txt
#   org-britishcouncil-20220903001812.txt
#   org-britishcouncil-20200522151822.txt
#   org-britishcouncil-20240514143549.txt
#   org-britishcouncil-20131220213527.txt
#   org-britishcouncil-20180209070522.txt
#   org-britishcouncil-20120620145849.txt
#   org-britishcouncil-20220326000942.txt
#   org-britishcouncil-20061009224039.txt
#   org-britishcouncil-20230728125810.txt
#   org-britishcouncil-20200302111731.txt
#   org-britishcouncil-20220619024954.txt
#   org-britishcouncil-20191028121400.txt
#   org-britishcouncil-20080803024158.txt
#   org-britishcouncil-20210129162346.txt
#   org-britishcouncil-20210305115331.txt
#   org-britishcouncil-20211112161010.txt
#   org-britishcouncil-20140203181313.txt
#   org-britishcouncil-20220302043356.txt
#   org-britishcouncil-20220520201638.txt
#   org-britishcouncil-20230526202157.txt
#   org-britishcouncil-20131220175633.txt
#   org-britishcouncil-20220509201056.txt
#   org-britishcouncil-20201030143031.txt
#   org-britishcouncil-20210701210636.txt
#   org-britishcouncil-20040117003731.txt
#   org-britishcouncil-20230303181933.txt
#   org-britishcouncil-20220527155829.txt
#   org-britishcouncil-20120607165615.txt
#   org-britishcouncil-20130313094049.txt
#   org-britishcouncil-20181207120100.txt
#   org-britishcouncil-20151013143608.txt
#   org-britishcouncil-20061023204137.txt
#   org-britishcouncil-20171123152225.txt
#   org-britishcouncil-20210611103847.txt
#   org-britishcouncil-20240105151208.txt
#   org-britishcouncil-20231018112106.txt
#   org-britishcouncil-20130815104756.txt
#   org-britishcouncil-20210728145207.txt
#   org-britishcouncil-20121107104523.txt
#   org-britishcouncil-20120823122955.txt
#   org-britishcouncil-20240122151045.txt
#   org-britishcouncil-20230114063307.txt
#   org-britishcouncil-20060921030838.txt
#   org-britishcouncil-20220914151751.txt
#   org-britishcouncil-20220319021857.txt
#   org-britishcouncil-20220201190610.txt
#   org-britishcouncil-20220508214923.txt
#   org-britishcouncil-20120903210238.txt
#   org-britishcouncil-20210901101413.txt
#   org-britishcouncil-20220203165946.txt
#   org-britishcouncil-20120711133552.txt
#   org-britishcouncil-20190902194447.txt
#   org-britishcouncil-20200731105505.txt
#   org-britishcouncil-20190205025939.txt
#   org-britishcouncil-20220429174758.txt
#   org-britishcouncil-20220812111025.txt
#   org-britishcouncil-20221029020452.txt
#   org-britishcouncil-20220201175608.txt
#   org-britishcouncil-20220721154035.txt
#   org-britishcouncil-20211113001710.txt
#   org-britishcouncil-20200910211411.txt
#   org-britishcouncil-20140304101922.txt
#   org-britishcouncil-20200616021003.txt
#   org-britishcouncil-20131112164331.txt
#   org-britishcouncil-20170909124320.txt
#   org-britishcouncil-20120627235804.txt
#   org-britishcouncil-20200205114610.txt
#   org-britishcouncil-20140713195124.txt
#   org-britishcouncil-20120705151950.txt
#   org-britishcouncil-20130123161218.txt
#   org-britishcouncil-20230630144357.txt
#   org-britishcouncil-20190802204658.txt
#   org-britishcouncil-20220912152147.txt
#   org-britishcouncil-20201009103437.txt
#   org-britishcouncil-20200907101937.txt
#   org-britishcouncil-20220730070812.txt
#   org-britishcouncil-20211103234315.txt
#   org-britishcouncil-20200911112257.txt
#   org-britishcouncil-20210126201727.txt
#   org-britishcouncil-20200308205333.txt
#   org-britishcouncil-20120618170729.txt
#   org-britishcouncil-20211105162015.txt
#   org-britishcouncil-20210201173639.txt
#   org-britishcouncil-20200318111558.txt
#   org-britishcouncil-20210806234105.txt
#   org-britishcouncil-20230602211853.txt
#   org-britishcouncil-20220318162529.txt
#   org-britishcouncil-20230301133346.txt
#   org-britishcouncil-20190514225023.txt
#   org-britishcouncil-20190301130027.txt
#   org-britishcouncil-20130626151040.txt
#   org-britishcouncil-20221014210615.txt
#   org-britishcouncil-20180903111628.txt
#   org-britishcouncil-20230414163711.txt
#   org-britishcouncil-20210807083045.txt
#   org-britishcouncil-20160512103339.txt
#   org-britishcouncil-20210301113747.txt
#   org-britishcouncil-20230217212102.txt
#   org-britishcouncil-20201127201226.txt
#   org-britishcouncil-20040725072939.txt
#   org-britishcouncil-20120705162242.txt
#   org-britishcouncil-20210416152201.txt
#   org-britishcouncil-20080720230235.txt
#   org-britishcouncil-20200308083429.txt
#   org-britishcouncil-20241008092012.txt
#   org-britishcouncil-20220513152323.txt
#   org-britishcouncil-20200602012141.txt
#   org-britishcouncil-20230421141608.txt
#   org-britishcouncil-20200503210228.txt
#   org-britishcouncil-20120628184337.txt
#   org-britishcouncil-20220202173407.txt
#   org-britishcouncil-20211004225736.txt
#   org-britishcouncil-20120729171106.txt
#   org-britishcouncil-20220131193819.txt
#   org-britishcouncil-20131203145214.txt
#   org-britishcouncil-20240215152724.txt
#   org-britishcouncil-20120823204914.txt
#   org-britishcouncil-20221224215530.txt
#   org-britishcouncil-20150915191848.txt
#   org-britishcouncil-20180302084420.txt
#   org-britishcouncil-20210223200935.txt
#   org-britishcouncil-20080908175447.txt
#   org-britishcouncil-20120620142053.txt
#   org-britishcouncil-20180313172835.txt
#   org-britishcouncil-20221209180941.txt
#   org-britishcouncil-20120912104640.txt
#   org-britishcouncil-20120905121843.txt
#   org-britishcouncil-20230714214318.txt
#   org-britishcouncil-20220312081234.txt
#   org-britishcouncil-20140106162018.txt
#   org-britishcouncil-20120725130838.txt
#   org-britishcouncil-20211021125830.txt
#   org-britishcouncil-20210714230749.txt
#   org-britishcouncil-20200828135949.txt
#   org-britishcouncil-20210903103540.txt
#   org-britishcouncil-20230224145207.txt
#   org-britishcouncil-20230602145229.txt
#   org-britishcouncil-20191212010114.txt
#   org-britishcouncil-20200418050657.txt
#   org-britishcouncil-20220923170225.txt
#   org-britishcouncil-20210219182910.txt
#   org-britishcouncil-20191122161814.txt
#   org-britishcouncil-20070706111611.txt
#   org-britishcouncil-20220804155703.txt
#   org-britishcouncil-20120905103456.txt
#   org-britishcouncil-20231103143423.txt
#   org-britishcouncil-20201211125814.txt
#   org-britishcouncil-20170721170231.txt
#   org-britishcouncil-20220624152218.txt
#   org-britishcouncil-20150323195600.txt
#   org-britishcouncil-20201006230036.txt
#   org-britishcouncil-20191031232838.txt
#   org-britishcouncil-20130903113854.txt
#   org-britishcouncil-20130221174058.txt
#   org-britishcouncil-20220218230743.txt
#   org-britishcouncil-20220301115054.txt
#   org-britishcouncil-20230113141754.txt
#   org-britishcouncil-20120910104054.txt
#   org-britishcouncil-20210630225155.txt
#   org-britishcouncil-20211028022228.txt
#   org-britishcouncil-20180109155021.txt
#   org-britishcouncil-20220708160550.txt
#   org-britishcouncil-20200716233031.txt
#   org-britishcouncil-20190613172844.txt
#   org-britishcouncil-20140908164211.txt
#   org-britishcouncil-20211231185507.txt
#   org-britishcouncil-20200605102803.txt
#   org-britishcouncil-20230714082315.txt
#   org-britishcouncil-20200428123015.txt
#   org-britishcouncil-20230623201653.txt
#   org-britishcouncil-20120613161739.txt
#   org-britishcouncil-20210323150241.txt
#   org-britishcouncil-20220129064045.txt
#   org-britishcouncil-20210610020756.txt
#   org-britishcouncil-20190603223006.txt
#   org-britishcouncil-20120830122906.txt
#   org-britishcouncil-20180718193515.txt
#   org-britishcouncil-20121106193433.txt
#   org-britishcouncil-20200327115836.txt
#   org-britishcouncil-20120806231310.txt
#   org-britishcouncil-20211219054300.txt
#   org-britishcouncil-20200417104612.txt
#   org-britishcouncil-20220709002144.txt
#   org-britishcouncil-20190613135738.txt
#   org-britishcouncil-20130701154029.txt
#   org-britishcouncil-20070109214310.txt
#   org-britishcouncil-20210407102813.txt
#   org-britishcouncil-20220909151103.txt
#   org-britishcouncil-20201218162646.txt
#   org-britishcouncil-20171123155658.txt
#   org-britishcouncil-20140801140646.txt
#   org-britishcouncil-20220826152615.txt
#   org-britishcouncil-20181030164704.txt
#   org-britishcouncil-20220201181126.txt
#   org-britishcouncil-20220819225404.txt
#   org-britishcouncil-20191212184536.txt
#   org-britishcouncil-20170804204404.txt
#   org-britishcouncil-20141205161257.txt
#   org-britishcouncil-20190309010737.txt
#   org-britishcouncil-20211015155248.txt
#   org-britishcouncil-20130106105341.txt
#   org-britishcouncil-20211014041736.txt
#   org-britishcouncil-20200702032027.txt
#   org-britishcouncil-20130922122450.txt
#   org-britishcouncil-20241010093758.txt
#   org-britishcouncil-20230120213047.txt
#   org-britishcouncil-20190510133550.txt
#   org-britishcouncil-20200909154828.txt
#   org-britishcouncil-20200922150552.txt
#   org-britishcouncil-20230127210843.txt
#   org-britishcouncil-20070603175210.txt
#   org-britishcouncil-20221203041512.txt
#   org-britishcouncil-20211001232750.txt
#   org-britishcouncil-20180106112841.txt
#   org-britishcouncil-20200320163811.txt
#   org-britishcouncil-20241008092028.txt
#   org-britishcouncil-20120628165344.txt
#   org-britishcouncil-20221111215415.txt
#   org-britishcouncil-20220409004624.txt
#   org-britishcouncil-20171112094328.txt
#   org-britishcouncil-20211204115532.txt
#   org-britishcouncil-20120616234107.txt
#   org-britishcouncil-20220402080550.txt
#   org-britishcouncil-20220208184012.txt
#   org-britishcouncil-20211126232608.txt
#   org-britishcouncil-20210925024949.txt
#   org-britishcouncil-20200619101939.txt
#   org-britishcouncil-20210506105028.txt
#   org-britishcouncil-20230324142930.txt
#   org-britishcouncil-20220827064437.txt
#   org-britishcouncil-20200703153032.txt
#   org-britishcouncil-20220114223536.txt
#   org-britishcouncil-20220304235608.txt
#   org-britishcouncil-20120905162736.txt
#   org-britishcouncil-20140611085722.txt
#   org-britishcouncil-20130703133346.txt
#   org-britishcouncil-20070205160144.txt
#   org-britishcouncil-20080712225821.txt
#   org-britishcouncil-20220607013851.txt
#   org-britishcouncil-20220209185725.txt
#   org-britishcouncil-20160307203042.txt
#   org-britishcouncil-20080731194805.txt
#   org-britishcouncil-20200519222607.txt
#   org-britishcouncil-20190111204546.txt
#   org-britishcouncil-20131001193032.txt
#   org-britishcouncil-20120804043108.txt
#   org-britishcouncil-20120708192610.txt
#   org-britishcouncil-20230519133500.txt
#   org-britishcouncil-20231215154520.txt
#   org-britishcouncil-20200515152229.txt
#   org-britishcouncil-20220304160843.txt
#   org-britishcouncil-20201020200355.txt
#   org-britishcouncil-20140711140856.txt
#   org-britishcouncil-20230519193527.txt
#   org-britishcouncil-20220107220639.txt
#   org-britishcouncil-20220901104620.txt
#   org-britishcouncil-20201120170316.txt
#   org-britishcouncil-20120619224325.txt
#   org-britishcouncil-20200717113729.txt
#   org-britishcouncil-20200529154542.txt
#   org-britishcouncil-20220211190018.txt
#   org-britishcouncil-20210113133547.txt
#   org-britishcouncil-20130904001227.txt
#   org-britishcouncil-20220224165101.txt
#   org-britishcouncil-20161026104325.txt
#   org-britishcouncil-20220919191619.txt
#   org-britishcouncil-20130301170524.txt
#   org-britishcouncil-20201224153753.txt
#   org-britishcouncil-20120619175639.txt
#   org-britishcouncil-20210106181642.txt
#   org-britishcouncil-20120816211332.txt
#   org-britishcouncil-20200428092837.txt
#   org-britishcouncil-20180103191718.txt
#   org-britishcouncil-20130206063133.txt
#   org-britishcouncil-20220201232334.txt
#   org-britishcouncil-20230630185126.txt
#   org-britishcouncil-20230616190046.txt
#   org-britishcouncil-20221105013521.txt
#   org-britishcouncil-20210905083026.txt
#   org-britishcouncil-20220408155646.txt
#   org-britishcouncil-20220127163941.txt
#   org-britishcouncil-20170203140607.txt
#   org-britishcouncil-20210413222932.txt
#   org-britishcouncil-20121004082420.txt
#   org-britishcouncil-20200701172543.txt
#   org-britishcouncil-20200917114818.txt
#   org-britishcouncil-20210909014716.txt
#   org-britishcouncil-20231018110859.txt
#   org-britishcouncil-20210827045110.txt
#   org-britishcouncil-20130321031234.txt
#   org-britishcouncil-20171012172357.txt
#   org-britishcouncil-20121204120829.txt
#   org-britishcouncil-20240306053301.txt
#   org-britishcouncil-20230908144838.txt
#   org-britishcouncil-20220210210011.txt
#   org-britishcouncil-20150903125703.txt
#   org-britishcouncil-20120619191743.txt
#   org-britishcouncil-20071003005144.txt
#   org-britishcouncil-20180825064055.txt
#   org-britishcouncil-20120824141747.txt
#   org-britishcouncil-20040104235635.txt
#   org-britishcouncil-20230505142017.txt
#   org-britishcouncil-20230106173827.txt
#   org-britishcouncil-20080609144936.txt
#   org-britishcouncil-20210820154031.txt
#   org-britishcouncil-20210318200746.txt
#   org-britishcouncil-20170914103839.txt
#   org-britishcouncil-20120913100828.txt
#   org-britishcouncil-20071104152643.txt
#   org-britishcouncil-20200501161349.txt
#   org-britishcouncil-20140320141334.txt
#   org-britishcouncil-20061003230950.txt
#   org-britishcouncil-20070305193039.txt
#   org-britishcouncil-20151020060703.txt
#   org-britishcouncil-20120703122451.txt
#   org-britishcouncil-20120619104037.txt
#   org-britishcouncil-20120705131111.txt
#   org-britishcouncil-20130502205830.txt
#   org-britishcouncil-20200424110923.txt
#   org-britishcouncil-20190715170347.txt
#   org-britishcouncil-20120705154730.txt
#   org-britishcouncil-20211223210730.txt
#   org-britishcouncil-20120613114312.txt
#   org-britishcouncil-20070402123942.txt
#   org-britishcouncil-20221022003640.txt
#   org-britishcouncil-20220923150742.txt
#   org-britishcouncil-20210623221805.txt
#   org-britishcouncil-20220801162541.txt
#   org-britishcouncil-20200925105813.txt
#   org-britishcouncil-20170914104401.txt
#   org-britishcouncil-20231020141904.txt
#   org-britishcouncil-20220715191408.txt
#   org-britishcouncil-20241008091430.txt
#   org-britishcouncil-20131205143304.txt
#   org-britishcouncil-20130125122900.txt
#   org-britishcouncil-20210625173259.txt
#   org-britishcouncil-20231117162845.txt
#   org-britishcouncil-20170721154016.txt
#   org-britishcouncil-20240104132726.txt
#   org-britishcouncil-20230610010931.txt
#   org-britishcouncil-20240206090434.txt
#   org-britishcouncil-20210917164422.txt
#   org-britishcouncil-20220401182034.txt
#   org-britishcouncil-20211126162941.txt
#   org-britishcouncil-20220420013311.txt
#   org-britishcouncil-20230210145115.txt
#   org-britishcouncil-20120904081913.txt
#   org-britishcouncil-20230127142737.txt
#   org-britishcouncil-20220928201327.txt
#   org-britishcouncil-20190308215635.txt
#   org-britishcouncil-20220414104606.txt
#   org-britishcouncil-20201204164248.txt
#   org-britishcouncil-20240104163043.txt
#   org-britishcouncil-20221209200821.txt
#   org-britishcouncil-20230825105717.txt
#   org-britishcouncil-20140108053044.txt
#   org-britishcouncil-20121005145737.txt
#   org-britishcouncil-20170109174948.txt
#   org-britishcouncil-20150305093332.txt
#   org-britishcouncil-20130430155626.txt
#   org-britishcouncil-20190715150915.txt
#   metadata.json
#   org-britishcouncil-20201104121946.txt
#   org-britishcouncil-20220121115734.txt
#   org-britishcouncil-20240725073649.txt
#   org-britishcouncil-20220601125742.txt
#   org-britishcouncil-20230925143119.txt
#   org-britishcouncil-20220121231853.txt
#   org-britishcouncil-20100104181058.txt

# %%
# Tar/gzip the current domain folder
# !tar -czf text-ukgwa.tar.gz text-ukgwa

# %%
# Display a link to the gzipped data
# In JupyterLab you'll need to Shift+right-click on the link and choose 'Download link'
display(FileLink("text-ukgwa.tar.gz"))
# Out:
# /home/gustavo/Escritorio/DHNB2025/notebooks-wac/workshop-notebooks-wac-dhnb2025/notebooks/text-ukgwa.tar.gz

# %% [markdown]
# ----
# Created by [Tim Sherratt](https://timsherratt.org) for the [GLAM Workbench](https://glam-workbench.github.io). This work has been adapted for the workshop "Web Archives Collections as data" as part of the [DHNB 2025 conference](https://dhnb.eu/conferences/dhnb2025/workshops/web-archive-collections-as-data/).
#
# Work on this notebook was supported by the [IIPC Discretionary Funding Programme 2019-2020](http://netpreserve.org/projects/).
#
# The Web Archives section of the GLAM Workbench is sponsored by the [British Library](https://www.bl.uk/).
